# %% [markdown]
# Hi in this Notebook we will be creating a Semantic Search app based on meaning and context rather that keywords.

# %%
# !pip install cohere
#!pip install python-dotenv
# !pip install weaviate-client
# !pip install pandas

# %% [markdown]
# We will first start by installing the libraries we need for the search engine. We will need at the start ***cohere LLM*** as Base model and ***Weaviate*** as the search engine and vector Database .

# %%
import cohere
from dotenv import load_dotenv
import os
import pandas as pd
import weaviate
import weaviate.classes as wvc
import weaviate.classes.config as wc
import time

from weaviate.classes.config import Integrations

# %%
#Load the API keys and the Cluster URL
#You can use  online cluster or local cluster
load_dotenv()
cohere_api = os.getenv("COHERE_API_KEY")
weaviate_api = os.getenv("WEAVIATE_API_KEY")
clusterUrl = os.getenv("WEAVIATE_CLUSTER_URL")
rpm_embeddings=100

# %%
#Create a Cohere CLient
co = cohere.Client(cohere_api)

# %%
#Create the Weaviate Client and the Cluster for DataBase

# authConfig = weaviate.auth.AuthApiKey(weaviate_api)
# client = weaviate.connect_to_wcs(
#     cluster_url=clusterUrl,
#     auth_credentials=authConfig,
#     headers={'X-Cohere-Api-Key': cohere_api},
#     skip_init_checks=True
# )

# %%
#Create Local Weaviate Client and the Cluster
client = weaviate.connect_to_local(
    skip_init_checks=True
)
integrations=[
    Integrations.cohere(
        api_key=cohere_api,
        requests_per_minute_embeddings=rpm_embeddings,
    )
]
client.integrations.configure(integrations)

# %% [markdown]
# Now we can verify if our client is connected.

# %%
print(client.is_connected())
# Out:
# True

# %% [markdown]
# <h2>Vector Database Population</h2><br><br>
# Before starting the population process let's start by creating  a class for Book and to keep our system stable and coherant .<br> we start by deleting our Class and then choose the properties and keep only _Title_ , _Categories_ and _Description_ as semantic search criterias by specifying that they are the only parameters to be embedded .

# %%
client.collections.delete(name='Book')

# %%
questions = client.collections.create(
    name="Book",
    vectorizer_config=wc.Configure.Vectorizer.text2vec_cohere(),
    generative_config=wc.Configure.Generative.cohere(),
    properties=[
        wc.Property(name="title", data_type=wc.DataType.TEXT),
        wc.Property(name="isbn10", data_type=wc.DataType.TEXT, skip_vectorization=True),
        wc.Property(name="isbn13", data_type=wc.DataType.NUMBER, skip_vectorization=True),
        wc.Property(name="categories", data_type=wc.DataType.TEXT),
        wc.Property(name="thumbnail", data_type=wc.DataType.TEXT, skip_vectorization=True),
        wc.Property(name="description", data_type=wc.DataType.TEXT),
        wc.Property(name="num_pages", data_type=wc.DataType.NUMBER, skip_vectorization=True),
        wc.Property(name="average_rating", data_type=wc.DataType.NUMBER, skip_vectorization=True),
        wc.Property(name="published_year", data_type=wc.DataType.NUMBER, skip_vectorization=True),
        wc.Property(name="authors", data_type=wc.DataType.TEXT, skip_vectorization=True),
    ],)

# %%
def process(chunk,collection):
    for i,book in chunk.iterrows():
        properties = {
            "title": book['title'],
            "isbn10": book['isbn10'],
            "isbn13": book['isbn13'],
            "categories": book['categories'],
            "thumbnail": book['thumbnail'],
            "description": book['description'],
            "num_pages": book['num_pages'],
            "average_rating": book['average_rating'],
            "published_year": book['published_year'],
            "authors": book['authors'],
        }
        try:
            uuid = collection.data.insert(properties)
            print(f"Inserting : {book['title']}: {uuid}",end='\n')
        except Exception as e:
            print(f"Exception : {e}")

# %%
book_collections = client.collections.get('Book')

chunksize = 100
chunks = pd.read_csv("./books.csv",chunksize=chunksize)
current_book = None

for chunk in chunks:
    process(chunk,book_collections)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_13144\1770848290.py:4: ResourceWarning: unclosed file <_io.TextIOWrapper name='./books.csv' mode='r' encoding='utf-8'>
#   chunks = pd.read_csv("./books.csv",chunksize=chunksize)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# Inserting : Gilead: 91cc21bd-e447-4cbb-bb04-1c335115a61b
# Inserting : Spider's Web: bb970110-3385-4f93-a290-e2113fe57bf7
# Inserting : The One Tree: ced19992-baaf-453e-a77a-9771ca6760f5
# Inserting : Rage of angels: d01a3f05-17e4-448c-9a64-14b3eb76d11e
# Inserting : The Four Loves: f49f2b32-ba3d-4b25-a826-ce7596f0f334
# Inserting : The Problem of Pain: 7b99d185-ee2e-46ce-b719-2465bae90b29
# Inserting : An Autobiography: ed0afd1b-79cc-485e-8ba9-e9ba5d2474b5
# Inserting : Empires of the Monsoon: 0be5a2a8-61a6-4520-8d3b-8be9febeb52e
# Inserting : The Gap Into Madness: d9f5b9ae-3e87-475d-9312-003c8cfd0346
# Inserting : Master of the Game: 2c9caf9c-7b41-41eb-a360-f147a9f3c022
# Inserting : If Tomorrow Comes: b588827b-f711-4a74-8beb-26ab5c254a13
# Inserting : Assassin's Apprentice: 57c2b574-79bb-4c2f-98c0-b53def2603b9
# Inserting : Warhost of Vastmark: 594f88c6-24b6-424c-8dfd-9062ae994669
# Inserting : The Once and Future King: acac1c9e-c7c2-45c2-8880-91276fb9ae88
# Inserting : Murder in LaMut: 1d94481b-b37d-4c0c-a689-3791ef0d3fef
# Inserting : Jimmy the Hand: 612856fa-1d0c-416f-b7d0-8bd669c001b5
# Exception : Object was not added! Unexpected status code: 400, with response body: {'code': 400, 'message': 'parsing body body from "" failed, because invalid character \'N\' looking for beginning of value'}.
# Inserting : Witness for the Prosecution & Selected Plays: ed1e4817-1a4d-4364-95cf-5bbd8d1a44c1
# Inserting : The Little House: a2bd3ec2-279d-4cd0-a232-3643b447136d
# Inserting : Mystical Paths: 36b4b92b-0a62-405d-8919-9a569662f807
# Inserting : Glittering Images: 683bba4b-c1e8-4f71-80a6-f63fe33a35fc
# Inserting : Glamorous Powers: 72a5b243-9d6c-44a9-bb11-21b7ec1ec9f2
# Inserting : The Mad Ship: 750af846-4430-4681-ba19-49c2b31de400
# Inserting : Post Captain: 83821f6c-8df7-473f-8aa2-0ab98c95a27e
# Inserting : The Reverse of the Medal: 684d7dfc-bbc6-41d9-ba28-4589cd270b09
# Inserting : Miss Marple: edda233f-d3c5-447f-b1f5-f8d91fd49e7d
# Inserting : The Years of Rice and Salt: b67def99-484a-41bc-9b76-277a390e4228
# Inserting : Spares: c1345f39-523b-454b-a85d-a314e5d487a3
# Inserting : Gravity: bc107ce6-6489-42b9-aef0-09898994f53c
# Inserting : The Wise Woman: 837b9848-bcca-490c-b357-d8968be30be4
# Inserting : Girls' Night in: 9e305545-af40-43a9-92e9-74bfdc3f75eb
# Inserting : The White Album: df44a0d8-10ec-41c9-9f0f-622a1fa5ea85
# Inserting : The Bonesetter's Daughter: 2ff244bf-0e69-47c0-972b-eac2616cb269
# Inserting : The Lexus and the Olive Tree: dc4045df-d541-48d9-a9b7-6deb09e04702
# Inserting : 'Tis: 736e4da6-df37-4b82-8646-a69c2f774277
# Inserting : Ocean Star Express: 730f4639-74e0-439d-b8b6-c82fe3c36cf1
# Inserting : A Small Pinch of Weather: 297cbfbc-9e91-4354-a5c0-437e80c890ae
# Exception : Object was not added! Unexpected status code: 400, with response body: {'code': 400, 'message': 'parsing body body from "" failed, because invalid character \'N\' looking for beginning of value'}.
# Inserting : Koko: 123e4faa-9e7b-4f75-9efc-d8e1b9fd8db2
# Inserting : Tree and Leaf: 9e7d1699-1908-4264-a987-d51f65e936f8
# Inserting : Partners in Crime: a420c194-eeb8-493f-8cbf-4aa2ad90d4eb
# Inserting : Murder in Mesopotamia: cf9e4edd-493f-4680-80d1-c5ae90172598
# Inserting : The Lord of the Rings, the Return of the King: a3cb65f7-8b9b-4bd1-a38f-a9138158aa06
# Inserting : All Families are Psychotic: 9eacb5cd-e0f4-44f1-8124-ef1d5542e6c8
# Inserting : Death in the Clouds: 66bed636-82cc-488a-b9a5-1d4fafe77649
# Inserting : Appointment with Death: c164ac44-6665-4861-8dbb-ff6dd3feda7d
# Inserting : Hallowe'en Party: bd42f635-a158-4e19-ba3e-c23ecadba667
# Inserting : Hercule Poirot's Christmas: 71277ade-a822-4ea3-adf6-0bd4b47f58e6
# Inserting : The Big Four: 8647dd4d-71a8-48e1-b7b5-a5c6ee2fbc76
# Inserting : The Thirteen Problems: b65cd228-577d-4a6f-96d2-59c38203f6d5
# Inserting : They Do it with Mirrors: 267c907c-2e0f-48a6-b209-d99abbeea793
# Inserting : A Murder is Announced: 5ec688bb-0358-4295-90a2-664476c29cb3
# Inserting : The Mirror Crack'd from Side to Side: e5a8774e-516c-4b85-a0e5-7158c44725b2
# Inserting : Mrs McGinty's Dead: ae142ed4-2cdf-4e10-941e-d4da53bbc98c
# Inserting : Taken at the Flood: ad352725-4d7e-41ff-9bbb-30d319652bcd
# Inserting : The Hollow: d5c40f98-8fdc-4ada-8d24-c3812e602c29
# Inserting : Third Girl: 2c55a3fb-6e46-4128-b521-e29ec381d1dc
# Inserting : The Secret of Chimneys: 7e32f924-2b44-4b6d-9ff8-a1a02eb6afb1
# Exception : Object was not added! Unexpected status code: 400, with response body: {'code': 400, 'message': 'parsing body body from "" failed, because invalid character \'N\' looking for beginning of value'}.
# Inserting : The Metaphysical Club: bf440470-3aee-471d-9ab1-59d722a52a04
# Exception : Object was not added! Unexpected status code: 400, with response body: {'code': 400, 'message': 'parsing body body from "" failed, because invalid character \'N\' looking for beginning of value'}.
# Inserting : Wilkins' Tooth: 502dc371-14fd-4f5d-8b04-7a66c85bd9cb
# Inserting : Cut: 18c04b83-cbcf-4031-afd9-7887fe7174c8
# Inserting : The Lord of the Rings: a1d8a55e-cfdf-4dc9-b4da-dedf7ccc8470
# Inserting : The Lord of the Rings: 345d32cc-cb45-480a-b0c8-4aa86155a944
# Inserting : The Fellowship of the Ring: abac659d-05c4-4f00-bfc0-0c136a934881
# Inserting : Lirael: 28908bc7-64ed-4ead-8a68-26dd865501f8
# Inserting : Tales from the Perilous Realm: 44410aaa-ce75-4006-a3f2-121824478cea
# Inserting : Breaking Open the Head: b0db09ff-8886-4b4c-93ec-1cf1b636135a
# Inserting : The Yiddish Policemen's Union: 31f37b72-2e05-4a6f-9cb8-7a443febaf0c
# Inserting : Beware, Princess Elizabeth: be160ef5-8630-4626-b3e2-d7065b2d42cb
# Inserting : The Family Way: 8c9d0f16-92a2-42a4-a923-4c2744027a59
# Inserting : Endless Night: 314b484c-5a05-4b3b-97b9-7468dba962b7
# Inserting : How to be Alone: 44f308f1-9bec-40bb-b6e1-f4e54dcd8bce
# Inserting : The Mysterious Mr. Quin: 3a609092-ff1b-4d86-bd7f-6858386ed875
# Inserting : The Listerdale Mystery: 209b15b2-9792-4fc3-92f9-d2bcacb59702
# Inserting : The Real Trial of Oscar Wilde: 04bc0cca-c8a2-4ca0-8096-c52642f6bd9f
# Inserting : I Can Read with Me Eyes Shut!: e6e6c27e-474f-48bc-b998-da08796175f3
# Inserting : Oh, the Places You'll Go!: 4e60806d-b34e-493c-89da-f8b8d03efa7d
# Inserting : If I Die in a Combat Zone: b53be2df-2daa-434f-b330-ab0b6d5c4302
# Inserting : The Return of the King: 7ab4aa59-7544-427b-9189-953eeafd6fcf
# Inserting : The Silmarillion: 4c36f6f2-3c3b-458c-845b-30ff597f7c78
# Inserting : I Wish that I Had Duck Feet: b3a79bbd-639a-4fa5-b17f-c37ff81661b6
# Inserting : Oh Say Can You Say?: 5f3c7ba9-203f-412a-b5f4-7f8b1aff0b7d
# Inserting : There's a Boy in the Girls' Bathroom: 99139016-e78f-4ad7-b29b-6a37153b7f36
# Inserting : Microserfs: d083b52f-f7b7-4a35-9b78-364eb9f5cb92
# Inserting : Miss Wyoming: 2d91ba3b-dc82-4c4e-83c0-1b3ef9481de7
# Inserting : Where Rainbows End: 3f277edc-5042-42c1-a6ea-2728c7f6d2cf
# Inserting : Poirot: 7e7ba7c3-080a-4d5f-ae94-4049f23a4e39
# Inserting : The Art of The Lord of the Rings: 1a032b34-9fea-461f-9745-c23f55fa5340
# Inserting : The Known World: c82ba843-1980-4887-86fe-620f5cef232d
# Inserting : Discover Your Destiny with the Monk Who Sold His Ferrari: 267705ba-1b1e-46e2-8b3a-12923ece5e39
# Inserting : Naked Lunch: 2348ed11-3828-4766-82f1-a86114d9d8ea
# Inserting : Tropic of Cancer: 61f05f9f-47c2-4b47-acc2-107ec364765d
# Inserting : Close Range: 37da3bc8-91b6-420e-aaa3-873459ca241c
# Inserting : The Love of the Last Tycoon: 6f479eef-8bc4-44cb-b4dd-dcc222f205bc
# Exception : Object was not added! Unexpected status code: 400, with response body: {'code': 400, 'message': 'parsing body body from "" failed, because invalid character \'N\' looking for beginning of value'}.
# Inserting : Heart Songs and Other Stories: 18e43bf5-02ca-4dd2-a16e-6755d74cd248
# Inserting : The voyage of the Dawn Treader: 3814c5de-815a-4f74-8b0e-2e56405b3944
# Exception : Object was not added! Unexpected status code: 400, with response body: {'code': 400, 'message': 'parsing body body from "" failed, because invalid character \'N\' looking for beginning of value'}.
# Inserting : The Short Stories of Ernest Hemingway: cd207dbd-b4cb-4dc7-8c62-0f11bb81ac09
# Exception : Object was not added! Unexpected status code: 400, with response body: {'code': 400, 'message': 'parsing body body from "" failed, because invalid character \'N\' looking for beginning of value'}.
# Exception : Object was not added! Unexpected status code: 400, with response body: {'code': 400, 'message': 'parsing body body from "" failed, because invalid character \'N\' looking for beginning of value'}.
# Inserting : The Elements of Style: 827a8d5c-d680-4961-9021-696ebf2216c5
# Inserting : The Presocratics: 90208c34-f046-475a-8785-9c7aeff5796c
# Exception : Object was not added! Unexpected status code: 400, with response body: {'code': 400, 'message': 'parsing body body from "" failed, because invalid character \'N\' looking for beginning of value'}.
# Exception : Object was not added! Unexpected status code: 400, with response body: {'code': 400, 'message': 'parsing body body from "" failed, because invalid character \'N\' looking for beginning of value'}.
# Exception : Object was not added! Unexpected status code: 400, with response body: {'code': 400, 'message': 'parsing body body from "" failed, because invalid character \'N\' looking for beginning of value'}.
# Inserting : Tyranny of the Majority: edd20f8c-0461-4203-a5a3-c83cd59eea5e
# Inserting : The Origins of the Civil Rights Movement: 7249bfc5-85d8-4e46-b8f9-f58994a5363d
# Inserting : Presidential Power and the Modern Presidents: 7d707e44-1993-459e-929b-177e62f06d05
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 400, with response body: {'code': 400, 'message': 'parsing body body from "" failed, because invalid character \'N\' looking for beginning of value'}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 400, with response body: {'code': 400, 'message': 'parsing body body from "" failed, because invalid character \'N\' looking for beginning of value'}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 400, with response body: {'code': 400, 'message': 'parsing body body from "" failed, because invalid character \'N\' looking for beginning of value'}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# ...
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Inserting : Mysteries of Pittsburgh: 6092da05-9168-4a1d-8ecf-c99d2fc429b3
# Inserting : Everything Is Illuminated tie-in: 40e45048-bccf-46be-a1bb-5bd7b4738587
# Inserting : Flight of the Nighthawks: 457e3411-a154-4185-b58a-ec9f7012fd58
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Inserting : The 3-Hour Diet (TM) On the Go (Collins Gem): 54f81dbe-4109-4b5a-8cbf-622f674b94df
# Inserting : The Best American Crime Writing 2006: 0cf550c9-3565-40b9-8b1b-c8ce3a0ab514
# Inserting : Last of the Wilds: 665dbd93-0a49-454f-90d5-c8680ba89fc6
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Inserting : Missing Mom: 202face9-bced-40b8-b000-407574e01382
# Inserting : The Collected Letters of C.S. Lewis, Volume 3: 6a3ec3d0-ceb2-4f33-920c-35baed19b648
# Inserting : Touch Not the Cat: e186e594-e2a6-462f-971d-04670a45cedc
# Inserting : King of the Vagabonds: 88247a80-f947-46c0-8f0e-de6844c6c5ca
# Inserting : Odalisque: 2e124251-9d10-4357-945f-0c7f07287795
# Inserting : Black Boy: 859b6ba8-232d-4661-ad03-601c21f0760d
# Exception : Object was not added! Unexpected status code: 400, with response body: {'code': 400, 'message': 'parsing body body from "" failed, because invalid character \'N\' looking for beginning of value'}.
# Inserting : Rat Bastards: 84b993c8-7ebe-4953-9297-4f74b0843daa
# Inserting : The Last Days of Henry VIII: abe4352b-4571-4584-bd86-0772eaac7b14
# Inserting : The Thorn Birds: 41e5bdcc-31db-4ffd-90a9-c71e4a182a60
# Inserting : Krakatoa: be882ce9-b746-4a4c-9412-66255e95ef2f
# Inserting : The Professor and the Madman: dd9077ae-869e-42bd-9044-50d849864993
# Exception : Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': "update vector: failed with status: 429 error: You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}]}.
# Inserting : The Curtain: 53fb9534-45f1-4301-a451-cfacb65e6cc5
# Inserting : A Hard Day's Write, 3e: 7e3b3427-d89f-4f1c-934d-387409d151b3
# Inserting : The Lion, the Witch and the Wardrobe Read-Aloud Edition: 661e1acd-0366-4c8c-9455-1fd2402e9995
# Inserting : Mambo Kings Play Songs of Love, The Tie-in: d6cf3a5d-76f1-43e7-8994-bccd9195f99e
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 8
#       5 current_book = None
#       7 for chunk in chunks:
# ----> 8     process(chunk,book_collections)
#
# Cell In[35], line 16, in process(chunk, collection)
#       3 properties = {
#       4     "title": book['title'],
#       5     "isbn10": book['isbn10'],
#    (...)
#      13     "authors": book['authors'],
#      14 }
#      15 try:
# ---> 16     uuid = collection.data.insert(properties)
#      17     print(f"Inserting : {book['title']}: {uuid}",end='\n')
#      18 except Exception as e:
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\weaviate\collections\data.py:390, in _DataCollection.insert(self, properties, references, uuid, vector)
#     387 if vector is not None:
#     388     weaviate_obj = self.__parse_vector(weaviate_obj, vector)
# --> 390 return self._insert(weaviate_obj)
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\weaviate\collections\data.py:83, in _Data._insert(self, weaviate_obj)
#      80 path = "/objects"
#      82 params, weaviate_obj = self.__apply_context_to_params_and_object({}, weaviate_obj)
# ---> 83 self._connection.post(
#      84     path=path,
#      85     weaviate_object=weaviate_obj,
#      86     params=params,
#      87     error_msg="Object was not added",
#      88     status_codes=_ExpectedStatusCodes(ok_in=200, error="insert object"),
#      89 )
#      90 return uuid_package.UUID(weaviate_obj["id"])
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\weaviate\connect\v4.py:500, in _Connection.post(self, path, weaviate_object, params, error_msg, status_codes)
#     492 def post(
#     493     self,
#     494     path: str,
#    (...)
#     498     status_codes: Optional[_ExpectedStatusCodes] = None,
#     499 ) -> Response:
# --> 500     return self.__send(
#     501         "POST",
#     502         url=self.url + self._api_version_path + path,
#     503         weaviate_object=weaviate_object,
#     504         params=params,
#     505         error_msg=error_msg,
#     506         status_codes=status_codes,
#     507     )
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\weaviate\connect\v4.py:449, in _Connection.__send(self, method, url, error_msg, status_codes, weaviate_object, params)
#     441 try:
#     442     req = self._client.build_request(
#     443         method,
#     444         url,
#    (...)
#     447         headers=self.__get_latest_headers(),
#     448     )
# --> 449     res = self._client.send(req)
#     450     if status_codes is not None and res.status_code not in status_codes.ok:
#     451         raise UnexpectedStatusCodeError(error_msg, response=res)
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
books = client.collections.get('Book')
print(books)
# Out:
# <weaviate.Collection config={
#   "name": "Book",
#   "description": null,
#   "generative_config": {
#     "generative": "generative-cohere",
#     "model": {}
#   },
#   "inverted_index_config": {
#     "bm25": {
#       "b": 0.75,
#       "k1": 1.2
#     },
#     "cleanup_interval_seconds": 60,
#     "index_null_state": false,
#     "index_property_length": false,
#     "index_timestamps": false,
#     "stopwords": {
#       "preset": "en",
#       "additions": null,
#       "removals": null
#     }
#   },
#   "multi_tenancy_config": {
#     "enabled": false,
#     "auto_tenant_creation": false,
#     "auto_tenant_activation": false
#   },
#   "properties": [
#     {
#       "name": "title",
#       "description": null,
#       "data_type": "text",
#       "index_filterable": true,
#       "index_searchable": true,
#       "nested_properties": null,
#       "tokenization": "word",
#       "vectorizer_config": {
#         "skip": false,
#         "vectorize_property_name": true
#       },
#       "vectorizer": "text2vec-cohere"
#     },
#     {
#       "name": "isbn10",
#       "description": null,
#       "data_type": "text",
#       "index_filterable": true,
#       "index_searchable": true,
#       "nested_properties": null,
#       "tokenization": "word",
#       "vectorizer_config": {
#         "skip": true,
#         "vectorize_property_name": true
#       },
#       "vectorizer": "text2vec-cohere"
#     },
#     {
#       "name": "isbn13",
#       "description": null,
#       "data_type": "number",
#       "index_filterable": true,
#       "index_searchable": false,
#       "nested_properties": null,
#       "tokenization": null,
#       "vectorizer_config": {
#         "skip": true,
#         "vectorize_property_name": true
#       },
#       "vectorizer": "text2vec-cohere"
#     },
#     {
#       "name": "categories",
#       "description": null,
#       "data_type": "text",
#       "index_filterable": true,
#       "index_searchable": true,
#       "nested_properties": null,
#       "tokenization": "word",
#       "vectorizer_config": {
#         "skip": false,
#         "vectorize_property_name": true
#       },
#       "vectorizer": "text2vec-cohere"
#     },
#     {
#       "name": "thumbnail",
#       "description": null,
#       "data_type": "text",
#       "index_filterable": true,
#       "index_searchable": true,
#       "nested_properties": null,
#       "tokenization": "word",
#       "vectorizer_config": {
#         "skip": true,
#         "vectorize_property_name": true
#       },
#       "vectorizer": "text2vec-cohere"
#     },
#     {
#       "name": "description",
#       "description": null,
#       "data_type": "text",
#       "index_filterable": true,
#       "index_searchable": true,
#       "nested_properties": null,
#       "tokenization": "word",
#       "vectorizer_config": {
#         "skip": false,
#         "vectorize_property_name": true
#       },
#       "vectorizer": "text2vec-cohere"
#     },
#     {
#       "name": "num_pages",
#       "description": null,
#       "data_type": "number",
#       "index_filterable": true,
#       "index_searchable": false,
#       "nested_properties": null,
#       "tokenization": null,
#       "vectorizer_config": {
#         "skip": true,
#         "vectorize_property_name": true
#       },
#       "vectorizer": "text2vec-cohere"
#     },
#     {
#       "name": "average_rating",
#       "description": null,
#       "data_type": "number",
#       "index_filterable": true,
#       "index_searchable": false,
#       "nested_properties": null,
#       "tokenization": null,
#       "vectorizer_config": {
#         "skip": true,
#         "vectorize_property_name": true
#       },
#       "vectorizer": "text2vec-cohere"
#     },
#     {
#       "name": "published_year",
#       "description": null,
#       "data_type": "number",
#       "index_filterable": true,
#       "index_searchable": false,
#       "nested_properties": null,
#       "tokenization": null,
#       "vectorizer_config": {
#         "skip": true,
#         "vectorize_property_name": true
#       },
#       "vectorizer": "text2vec-cohere"
#     },
#     {
#       "name": "authors",
#       "description": null,
#       "data_type": "text",
#       "index_filterable": true,
#       "index_searchable": true,
#       "nested_properties": null,
#       "tokenization": "word",
#       "vectorizer_config": {
#         "skip": true,
#         "vectorize_property_name": true
#       },
#       "vectorizer": "text2vec-cohere"
#     }
#   ],
#   "references": [],
#   "replication_config": {
#     "factor": 1
#   },
#   "reranker_config": null,
#   "sharding_config": {
#     "virtual_per_physical": 128,
#     "desired_count": 1,
#     "actual_count": 1,
#     "desired_virtual_count": 128,
#     "actual_virtual_count": 128,
#     "key": "_id",
#     "strategy": "hash",
#     "function": "murmur3"
#   },
#   "vector_index_config": {
#     "quantizer": null,
#     "cleanup_interval_seconds": 300,
#     "distance_metric": "cosine",
#     "dynamic_ef_min": 100,
#     "dynamic_ef_max": 500,
#     "dynamic_ef_factor": 8,
#     "ef": -1,
#     "ef_construction": 128,
#     "flat_search_cutoff": 40000,
#     "max_connections": 32,
#     "skip": false,
#     "vector_cache_max_objects": 1000000000000
#   },
#   "vector_index_type": "hnsw",
#   "vectorizer_config": {
#     "vectorizer": "text2vec-cohere",
#     "model": {},
#     "vectorize_collection_name": true
#   },
#   "vectorizer": "text2vec-cohere",
#   "vector_config": null
# }>

# %% [markdown]
# Now we wil implement the semantic search using Weaviate.

# %%
#semantic search
book_collection= client.collections.get('Book')

response = book_collection.query.near_text(
    query="biology",
    limit=3
)

print()
for book in response.objects:
    print(book.properties['title'])
    print(book.properties['description'])
    print(book.properties['categories'])
    print('---')
# Out:
# Gravity
# Emma Watson a research physician has been training for the mission of a lifetime: to study living organisms in the microgravity of space. But the true and lethal nature of the experiment has not been revealed to NASA and once aboard the space station things start to go wrong. A culture of single-celled Archaeons, gathered from the deep sea, begin to rapidly multiply and infect the crew - with deadly and agonising results. As her estranged husband and ground crew at NASA work against the clock to launch a rescue Emma stuggles to contain the lethal microbe. But with the contagion threatening Earth's population, there are those who would leave the astronauts stranded in orbit, quarantined aboard the station.
# Science fiction
# ---
# The Problem of Pain
# "In The Problem of Pain, C.S. Lewis, one of the most renowned Christian authors and thinkers, examines a universally applicable question within the human condition: If God is good and all-powerful, why does he allow his creatures to suffer pain? With his signature wealth of compassion and insight, C.S. Lewis offers answers to these crucial questions and shares his hope and wisdom to help heal a world hungering for a true understanding of human nature."--Amazon.
# Christian life
# ---
# Spares
# Spares - human clones, the ultimate health insurance. An eye for an eye - but some people are doing all the taking. The story of Jack Randall: burnt-out, dropped out, and way overdrawn at the luck bank. But as caretaker on a Spares Farm, he still has a choice, and it might make a difference.
# Human cloning
# ---

# %%
# Generative Search
# response = book_collection.generate.near_text(
#     query="technology, data structures and algorithms, distributed systems",
#     limit=2,
#     single_prompt="Explain why this book might be interesting to someone who likes playing the violin, rock climbing, and doing yoga. the book's title is {title}, with a description: {description}, and is in the genre: {categories}."
# )
print(response.objects[0].generated)
# Out:
# Microserfs could be an intriguing read for someone who enjoys violin playing, rock climbing, and yoga because it offers a unique perspective on the lives of computer programmers, a world away from the activities you enjoy.
#
# The book provides an insightful glimpse into the lives of a group of Microsoft employees, known as microserfs, who are trying to find a balance between their demanding jobs and their personal lives. The characters' struggles to establish a sense of self and fulfill their passions outside of work could resonate with readers who have dedicated time and energy to mastering the violin, the physical challenges of rock climbing, and the mindfulness of yoga.
#
# The novel is also likely to provide an intriguing look into a different lifestyle and career path—one centered around computer programming. It might offer a fascinating glimpse into a world the reader might not otherwise experience, with an insider's view of the culture and work ethic at a giant tech corporation.
#
# Furthermore, the theme of finding time for personal pursuits despite the demands of a high-pressure job is a relatable one for anyone who has ever juggled work-life balance. The characters' journeys towards discovering their passions and making a change could be inspiring and might offer some food for thought on how to best manage one's own work-life priorities.
#
# So, for someone drawn to creative arts, physical challenges, and mindfulness, *Microserfs* could provide an intriguing contrast and offer a fascinating insight into a different lifestyle, while also exploring relevant themes of work-life balance and personal fulfillment.
